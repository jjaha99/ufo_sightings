# %% [markdown]
# <a href="https://colab.research.google.com/github/jjaha99/ufo_sightings/blob/main/kaggle_dataanalysis_ufosightings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.makedirs("data", exist_ok=True)
os.makedirs("outputs", exist_ok=True)
os.makedirs("figures", exist_ok=True)

print("Folders created:", os.listdir())
# Out:
# Folders created: ['.config', 'figures', 'data', 'outputs', 'sample_data']

# %%
import kagglehub
path = kagglehub.dataset_download("NUFORC/ufo-sightings")
# Out:
# ...
# 100%|██████████| 10.2M/10.2M [00:00<00:00, 100MB/s]
# Extracting files...

# %%
import shutil

shutil.copy(
    os.path.join(path, "scrubbed.csv"),
    "data/ufo_scrubbed.csv"
)

os.listdir("data")
# Out:
# ['ufo_scrubbed.csv']

# %%
import pandas as pd
df = pd.read_csv("data/ufo_scrubbed.csv")
df.head()
# Out:
# /tmp/ipython-input-651775536.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/ufo_scrubbed.csv")
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...
